# %% [markdown]
# # Development Stack Installation
# Written by <a href="mailto:aric.sanders@nist.gov">Aric Sanders</a>, 01/2016
#
# <hr style="height:1px">
# ## Git Installation
# <hr style="height:1px">
#
# 1. Download and install [Git] [git]
#     + Git is a version control program
#     + [Github][github] and [bitbucket][bitbucket] are good places to put repositories
#
# <hr style="height:1px">
# ## Python Base Installation
# <hr style="height:1px">
#
# 1. Install [Anaconda] [Anaconda]
#     + Use the python 2.7 installer
#     + This installs a large number of [packages] [Anaconda Packages]
#     + Includes [Jupyter] [jupyter], which is a mathematica style notebook for python.
#     + A good overview of jupyter's capability can be found [here] [brynmawr]
#     + in ubuntu down load the Anaconda package, from the directory run bash Anaconda....sh
# 2. Install [PyCharm] [PyCharm], Communtity Edition is free
#     + Pycharm is an IDE (Integrated Development Environment) for python
#     + It integrates very well with [git] [git], and it includes very good tools for
#     working with code, if you install [git][git] first it will autodetect it.
#     + Requires OpenJDK to be installed. The ubuntu command is sudo apt-get install openjdk-7-jre or JRE ( Windows ) to be installed.
#
# <hr style="height:1px">
# ## Python Package Installation
# <hr style="height:1px">
# ### For python packages using pip
# \$ pip install package, in ubuntu make sure you are a superuser, i.e. sudo
#
# or in python code
#
# ```python
#     import os
#     os.system(r'pip install pyvisa')
# ```
# 1. Install [Pdoc][pdoc]
#     + pdoc makes an html page given an import-able module
#     + pdoc.html('os') or a text version pdoc.text('os')
# 2. Install [NIVisa] [visa]
#     + NIVISA requires regstration but is free
#     + It allows communication through several methods including [GPIB][gpib]
#     + This is not a python package but you need it for pyvisa,
#     [pyvisa-py][pyvisa-py] looks to be a potential alternative.
# 3. Install [pyvisa][pyvisa]
# 4. Install [Django] [django]
# 5. Install [WxPython] [wx], not pip but there are prebuilt binaries
# 6. Install [odo] [odo], pip install has <em style="color:red;" >errors</em> on ubuntu.
# 7. Install django-registration and change registration/forms.py to include first_name and last_name on the user form
#     + at a command prompt: pip install django-registration
# 8. Install django-bootstrap-breadcrumbs
#     + at a command prompt: pip install django-bootstrap-breadcrumbs
# 9. Install markdown
#     + at a command prompt: pip install markdown
# 10. Install [Boa Constructor] [boa] for Wx FrontEnds creations
#     + choose boa-constructor-0.6.1.src.zip from the download page, the binary installers do not work if python is installed under the anaconda directory
#     + There some problems with the source code that must be fixed:
#         + All references to wx.NO_3D must be removed (I commented them out)
#             1. in prefs.rc.py
#                 + splitterStyle = wx.SP_LIVE_UPDATE | wx.SP_3DSASH
#                 + #removed option | wx.NO_3D,03/02/2016 Aric Sanders
#             2. in enumerations.py
#                 + windowNameStyles
#                 + #removed the option 'wx.NO_3D':wx.NO_3D, 03/02/2016 Aric Sanders
#                 + windowStyles
#                 + #removed the window style wx.NO_3D, 03/02/2016 Aric Sanders
#             3. in Inspector.py
#                 + self.categories
#                 + #removed the style wx.NO_3D | on 03/02/2016 Aric Sanders
#
#          + Because you unzipped the file into something like C:\python27\Lib\site-packages\boa-constructor-0.6.1,
#          you have to make a new folder Boa and add an __init__.py file to it.
#          + Now there are a lot of things improperly namespaced assuming that you will add an enviornmental variable to help it out. I renamspaced them to Boa.
#
# <hr style="height:1px">
# ## Inkscape Installation
# <hr style="height:1px">
#
# 1. Download and install [Inkscape] [Inkscape]
#     + Inkscape is a [svg] [svg] (scalable vector graphics) editor
#     + In ubuntu use sudo apt-get install inkscape at a terminal
#
#
#
# <hr style="height:1px">
# ## Open Office Installation
# <hr style="height:1px">
# 1. Download and install [open office] [open office]
#     + Open office can be scripted through pyuno to convert many formats
#     + This is really optional, any office suite with html conversion will work
#     + Ultimately the idea is to use [unoconv] [unoconv]
#
# [boa]:https://sourceforge.net/projects/boa-constructor/files/Boa-Constructor/0.6.1-beta/
# [Anaconda]:https://www.continuum.io/downloads
# [Anaconda Packages]:http://docs.continuum.io/anaconda/pkg-docs
# [PyCharm]:https://www.jetbrains.com/pycharm/download/#section=windows
# [Inkscape]:https://inkscape.org/en/download/
# [jupyter]:http://jupyter.org/
# [git]:https://git-scm.com/downloads
# [brynmawr]:http://jupyter.cs.brynmawr.edu/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb
# [github]:https://github.com/
# [bitbucket]:https://bitbucket.org/
# [svg]:https://en.wikipedia.org/wiki/Scalable_Vector_Graphics
# [visa]:http://www.ni.com/download/ni-visa-15.0.1/5693/en/
# [pyvisa]:https://pyvisa.readthedocs.org/en/stable/getting.html
# [django]:https://www.djangoproject.com/download/
# [wx]:http://wxpython.org/
# [odo]:https://odo.readthedocs.org/en/latest/
# [pdoc]:https://pypi.python.org/pypi/pdoc
# [gpib]:https://en.wikipedia.org/wiki/IEEE-488
# [pyvisa-py]:http://pyvisa-py.readthedocs.org/en/latest/
# [open office]:http://www.openoffice.org/download/
# [unoconv]:https://github.com/dagwieers/unoconv
